# %% [markdown]
# <a href="https://colab.research.google.com/github/hfairyz/AI_ML/blob/main/week5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # ch3

# %%
cd /content/drive/MyDrive/머신러닝/Pandas/ch_03
# Out:
# /content/drive/MyDrive/머신러닝/Pandas/ch_03

# %%
import pandas as pd

long_df = pd.read_csv(
    'data/long_data.csv', usecols=['date', 'datatype', 'value']
).rename(
    columns={'value': 'temp_C'}
).assign(
    date=lambda x: pd.to_datetime(x.date),
    temp_F=lambda x: (x.temp_C * 9/5) + 32
)
long_df.head()
# Out:
#   datatype       date  temp_C  temp_F
# 0     TMAX 2018-10-01    21.1   69.98
# 1     TMIN 2018-10-01     8.9   48.02
# 2     TOBS 2018-10-01    13.9   57.02
# 3     TMAX 2018-10-02    23.9   75.02
# 4     TMIN 2018-10-02    13.9   57.02

# %% [markdown]
# ## pivoting

# %%
pivoted_df = long_df.pivot(
    index='date', columns='datatype', values='temp_C'
)
pivoted_df.head()
# Out:
# datatype    TMAX  TMIN  TOBS
# date
# 2018-10-01  21.1   8.9  13.9
# 2018-10-02  23.9  13.9  17.2
# 2018-10-03  25.0  15.6  16.1
# 2018-10-04  22.8  11.7  11.7
# 2018-10-05  23.3  11.7  18.9

# %%
pivoted_df = long_df.pivot(
    index='date', columns='datatype', values=['temp_C', 'temp_F']
)
pivoted_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %%
pivoted_df.columns
# Out:
# MultiIndex([('temp_C', 'TMAX'),
#             ('temp_C', 'TMIN'),
#             ('temp_C', 'TOBS'),
#             ('temp_F', 'TMAX'),
#             ('temp_F', 'TMIN'),
#             ('temp_F', 'TOBS')],
#            names=[None, 'datatype'])

# %% [markdown]
# ## unstack

# %%
multi_index_df = long_df.set_index(['date', 'datatype'])
multi_index_df.head()
# Out:
#                      temp_C  temp_F
# date       datatype
# 2018-10-01 TMAX        21.1   69.98
#            TMIN         8.9   48.02
#            TOBS        13.9   57.02
# 2018-10-02 TMAX        23.9   75.02
#            TMIN        13.9   57.02

# %%
unstacked_df = multi_index_df.unstack()
unstacked_df.head()
# Out:
#            temp_C             temp_F
# datatype     TMAX  TMIN  TOBS   TMAX   TMIN   TOBS
# date
# 2018-10-01   21.1   8.9  13.9  69.98  48.02  57.02
# 2018-10-02   23.9  13.9  17.2  75.02  57.02  62.96
# 2018-10-03   25.0  15.6  16.1  77.00  60.08  60.98
# 2018-10-04   22.8  11.7  11.7  73.04  53.06  53.06
# 2018-10-05   23.3  11.7  18.9  73.94  53.06  66.02

# %% [markdown]
# ## melting

# %%
wide_df = pd.read_csv('data/wide_data.csv')
wide_df.head()
# Out:
#          date  TMAX  TMIN  TOBS
# 0  2018-10-01  21.1   8.9  13.9
# 1  2018-10-02  23.9  13.9  17.2
# 2  2018-10-03  25.0  15.6  16.1
# 3  2018-10-04  22.8  11.7  11.7
# 4  2018-10-05  23.3  11.7  18.9

# %%
melted_df = wide_df.melt(
    id_vars='date',
    value_vars=['TMAX', 'TMIN', 'TOBS'],
    value_name='temp_C',
    var_name='measurement'
)
melted_df.head()
# Out:
#          date measurement  temp_C
# 0  2018-10-01        TMAX    21.1
# 1  2018-10-02        TMAX    23.9
# 2  2018-10-03        TMAX    25.0
# 3  2018-10-04        TMAX    22.8
# 4  2018-10-05        TMAX    23.3

# %%
melted_df.tail()
# Out:
#           date measurement  temp_C
# 88  2018-10-27        TOBS     6.1
# 89  2018-10-28        TOBS     7.2
# 90  2018-10-29        TOBS     8.3
# 91  2018-10-30        TOBS     5.0
# 92  2018-10-31        TOBS     0.0

# %% [markdown]
# ## stack

# %%
wide_df.set_index('date', inplace=True)
wide_df.head()
# Out:
#             TMAX  TMIN  TOBS
# date
# 2018-10-01  21.1   8.9  13.9
# 2018-10-02  23.9  13.9  17.2
# 2018-10-03  25.0  15.6  16.1
# 2018-10-04  22.8  11.7  11.7
# 2018-10-05  23.3  11.7  18.9

# %%
stacked_series = wide_df.stack()
stacked_series.head()
# Out:
# date
# 2018-10-01  TMAX    21.1
#             TMIN     8.9
#             TOBS    13.9
# 2018-10-02  TMAX    23.9
#             TMIN    13.9
# dtype: float64

# %%
stacked_df = stacked_series.to_frame('values')
stacked_df.head()
# Out:
#                  values
# date
# 2018-10-01 TMAX    21.1
#            TMIN     8.9
#            TOBS    13.9
# 2018-10-02 TMAX    23.9
#            TMIN    13.9

# %% [markdown]
# # ch4

# %%
cd /content/drive/MyDrive/머신러닝/Pandas/ch_04
# Out:
# /content/drive/MyDrive/머신러닝/Pandas/ch_04

# %%
import pandas as pd
import numpy as np

weather = pd.read_csv('data/nyc_weather_2018.csv')
weather.head()
# Out:
#                   date datatype            station attributes  value
# 0  2018-01-01T00:00:00     PRCP  GHCND:US1CTFR0039       ,,N,    0.0
# 1  2018-01-01T00:00:00     PRCP  GHCND:US1NJBG0015       ,,N,    0.0
# 2  2018-01-01T00:00:00     SNOW  GHCND:US1NJBG0015       ,,N,    0.0
# 3  2018-01-01T00:00:00     PRCP  GHCND:US1NJBG0017       ,,N,    0.0
# 4  2018-01-01T00:00:00     SNOW  GHCND:US1NJBG0017       ,,N,    0.0

# %%
snow_data = weather.query('datatype == "PRCP" and station.str.contains("S0007")', engine='python')
snow_data.head()
# Out:
#                      date datatype            station attributes  value
# 79    2018-01-01T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 311   2018-01-02T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 545   2018-01-03T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 788   2018-01-04T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    4.1
# 1044  2018-01-05T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,   18.0

# %%
weather.loc[
    (weather.datatype == 'PRCP') 
    & weather.station.str.contains('S0007'), :
].head()
# Out:
#                      date datatype            station attributes  value
# 79    2018-01-01T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 311   2018-01-02T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 545   2018-01-03T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    0.0
# 788   2018-01-04T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,    4.1
# 1044  2018-01-05T00:00:00     PRCP  GHCND:US1NYNS0007       ,,N,   18.0

# %%
weather.describe(include='object')
# Out:
#                        date datatype            station attributes
# count                 78780    78780              78780      78780
# unique                  365       27                110         26
# top     2018-03-22T00:00:00     PRCP  GHCND:USW00094789       ,,N,
# freq                    296    27228               4270      34153

# %%
weather.describe(include='all')
# Out:
#                        date datatype            station attributes  \
# count                 78780    78780              78780      78780
# unique                  365       27                110         26
# top     2018-03-22T00:00:00     PRCP  GHCND:USW00094789       ,,N,
# freq                    296    27228               4270      34153
# mean                    NaN      NaN                NaN        NaN
# std                     NaN      NaN                NaN        NaN
# min                     NaN      NaN                NaN        NaN
# 25%                     NaN      NaN                NaN        NaN
# 50%                     NaN      NaN                NaN        NaN
# 75%                     NaN      NaN                NaN        NaN
# max                     NaN      NaN                NaN        NaN
#
#                value
# count   78780.000000
# unique           NaN
# top              NaN
# freq             NaN
# mean       44.951456
# std       192.835503
# ...

# %%
weather.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78780 entries, 0 to 78779
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        78780 non-null  object
#  1   datatype    78780 non-null  object
#  2   station     78780 non-null  object
#  3   attributes  78780 non-null  object
#  4   value       78780 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 3.0+ MB
